# %% [markdown]
# # Load  clean HIV tweets and sentiment tweets
# notebook code adapted from https://github.com/piskvorky/gensim/blob/develop/docs/notebooks/doc2vec-IMDB.ipynb
# sentiment training data from http://thinknook.com/wp-content/uploads/2012/09/Sentiment-Analysis-Dataset.zip

# %%
import re
import json
from collections import namedtuple

import gensim

train = False

def clean_text(text):
    clean = re.sub(r'http.*$', '', text)
    clean = re.sub(r'[^a-zA-Z,\.?\'#0-9\s\-_]', '', clean)
    
    clean = clean.replace('...', '.')
    clean = clean.replace(',', ' , ')
    clean = clean.replace('#', ' # ')
    clean = clean.replace('?', ' ? ')
    clean = clean.replace('!', ' ! ')
    
    clean = clean.lower()
    word_list = clean.split()
    
    return word_list

SentimentDocument = namedtuple('SentimentDocument', 'words tags split sentiment')


# start with sentiment data
sentiment_docs = []
with open('../data/sentiment_analysis_dataset.csv') as sentiment_data:
    for line_no, line in enumerate(sentiment_data):
        tokens = gensim.utils.to_unicode(line).split(',')
        words = clean_text(tokens[3])
        tags = ['sen_' + str(line_no)] # `tags = [tokens[0]]` would also work at extra memory cost
        split = ['train','train','train','valid'][line_no % 4]  # 3/4 training, 1/4 validation
        sentiment = tokens[1]
        sentiment_docs.append(SentimentDocument(words, tags, split, sentiment))
        
# now add our HIV/PrEP related tweets
hiv_docs = []
tweet_ids = set()
with open('../data/c_twitter.json') as hiv_prep_data:
    for line_no, line in enumerate(hiv_prep_data):
        twt = json.loads(line)
        words = twt['text'].split()
        tags = [str(twt['id'])]
        split = 'extra'
        sentiment = None
        if tags[0] not in tweet_ids:
            hiv_docs.append(SentimentDocument(words, tags, split, sentiment))
            tweet_ids.add(tags[0])

train_docs = [doc for doc in sentiment_docs if doc.split == 'train']
valid_docs = [doc for doc in sentiment_docs if doc.split == 'valid']
alldocs = sentiment_docs + hiv_docs

# shuffle for training
shuffledocs = alldocs[:]

# %% [markdown]
# # Build model

# %%
from gensim.models import Doc2Vec
import gensim.models.doc2vec
from collections import OrderedDict
import multiprocessing

cores = multiprocessing.cpu_count()
assert gensim.models.doc2vec.FAST_VERSION > -1, "this will be painfully slow otherwise"

model= Doc2Vec(dm=1, dm_mean=1, size=100, window=3, negative=5, hs=0, min_count=2, workers=cores,
           max_vocab_size=10000, seed=1)

model.build_vocab(alldocs)
print(model)
# Out:
# Doc2Vec(dm/m,d100,n5,w3,mc2,t6)

# %%
from sklearn.linear_model import LogisticRegression
import numpy as np

def fit_model_eval_accuracy(X, y, eval_X, eval_y):
    model = LogisticRegression(random_state=1)
    model.fit(X, y)
    
    mean_accuracy = model.score(eval_X, eval_y)
    
    return model, mean_accuracy

def predict_from_model(model, X):
    pred_y = model.predict(X)
    pred_log_prob = model.predict_log_proba(X)
    
    return (pred_y, pred_log_prob)

# %% [markdown]
# # Train
#
# (should add per-epoch shuffling for faster training)

# %%
from random import shuffle
import datetime
import pickle

passes = 20


if train:
    for epoch in range(passes):

        # train doc vectors
        shuffle(shuffledocs)
        model.train(shuffledocs)

        # train lr model
        X = np.zeros((len(train_docs), 100))
        y = np.zeros(len(train_docs))
        for i, doc in enumerate(train_docs):
            doc_id_str = doc[1][0]
            X[i,] = model.docvecs[doc_id_str]
            y[i] = int(doc[3])

        # validate lr model
        X_eval = np.zeros((len(valid_docs), 100))
        y_eval = np.zeros(len(valid_docs))
        for i, doc in enumerate(valid_docs):
            doc_id_str = doc[1][0]
            X_eval[i,] = model.docvecs[doc_id_str]
            y_eval[i] = int(doc[3])

        lr_model, mean_accuracy = fit_model_eval_accuracy(X, y, X_eval, y_eval)
        print('epoch:', epoch, 'mean accuracy:', mean_accuracy)
        
        model.save('../models/sentiment_analysis.model')
        
        s = pickle.dumps(lr_model)
        with open('../models/lr_sentiment.model', 'wb') as f_out:
            f_out.write(s)

else:
    Doc2Vec.load('../models/sentiment_analysis.model')
    
    with open('../models/lr_sentiment.model', 'rb') as f_in:
        s = f_in.read()
    lr_model = pickle.loads(s)

# %%
# evaluate HIV/PrEP sentiment
X = np.zeros((len(hiv_docs), 100))
words = []
for i, doc in enumerate(hiv_docs):
    doc_id_str = doc[1][0]
    X[i,] = model.docvecs[doc_id_str]
    words.append(' '.join(doc[0]))
pred_y, pred_log_prob = predict_from_model(lr_model, X)

# %%
import pandas as pd

pred_log_prob_neg = [e[0] for e in pred_log_prob]
pred_log_prob_pos = [e[1] for e in pred_log_prob]

index = [doc[1][0] for doc in hiv_docs]
data = np.array([pred_y, pred_log_prob_neg, pred_log_prob_pos, words])
df = pd.DataFrame(data=data.transpose(),
                  columns=['pred_y', 'pred_log_prob_neg', 'pred_log_prob_pos', 'words'],
                  index=index)
# add tweet id to this dataframe

# %%
# example HIV/PrEP tweets
# (negative at the top and positive at the bottom)
df = df.sort(columns='pred_log_prob_pos', ascending=True)
df
# Out:
# /home/ubuntu/Desktop/sm_w2v/venv/lib/python3.5/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()
#                    pred_y pred_log_prob_neg pred_log_prob_pos  \
# 706525326667550720    1.0       -1.03444581   -0.439161454208
# 685500898123083778    1.0    -1.03393874204   -0.439441164409
# 695750291338166272    1.0     -1.0335785384   -0.439639994668
# 671757652762980352    1.0    -1.03346429745   -0.439703078211
# 690280713963188224    1.0    -1.03339923158   -0.439739012409
# 667667693240246272    1.0    -1.03322957854   -0.439832724471
# 712971190860693504    1.0    -1.03293588354   -0.439995012538
# 675804767688372224    1.0    -1.03289141526   -0.440019590981
# 686419247736606720    1.0    -1.03288781043   -0.440021583508
# 714240257625960448    1.0     -1.0328843537   -0.440023494189
# 677140221381709824    1.0    -1.03284399727   -0.440045801654
# 709583191535845376    1.0    -1.03269895172   -0.440125988721
# 685497277918625793    1.0    -1.03268202136   -0.440135349689
# 717013167256121348    1.0    -1.03262745511   -0.440165521592
# 708375577665769473    1.0    -1.03259618637    -0.44018281251
# 692833356803760128    1.0    -1.03258201619   -0.440190648581
# 705158479846232065    1.0    -1.03257884047   -0.440192404768
# 709219826217127936    1.0      -1.032539839   -0.440213973467
# 671839149725380609    1.0    -1.03252182164   -0.440223937917
# 702877627518877696    1.0    -1.03251068239    -0.44023009859
# 697512318465413120    1.0    -1.03246013429   -0.440258056046
# 705144099612053504    1.0    -1.03241838861   -0.440281146662
# 709386625529290752    1.0    -1.03241380866   -0.440283680045
# 704547215889571841    1.0    -1.03239398293    -0.44029464677
# 673373343136006144    1.0    -1.03237625185   -0.440304455114
# 689338774627729408    1.0     -1.0323746637   -0.440305333647
# 704748453071458304    1.0    -1.03237281292   -0.440306357467
# 704762004561633280    1.0    -1.03235311148   -0.440317256134
# 698393412232413184    1.0    -1.03235072991   -0.440318573624
# 670555522735677440    1.0    -1.03234131984   -0.440323779328
# ...                   ...               ...               ...
# 671804970618847232    1.0    -1.00577077761   -0.455331953781
# 678767157287649281    1.0     -1.0057472299   -0.455345533916
# 687062507735756800    1.0     -1.0056339524   -0.455410868935
# 675926584356802560    1.0    -1.00555644212   -0.455455581238
# 710918709880160261    1.0    -1.00555465575   -0.455456611779
# 678704737533886464    1.0    -1.00551666862   -0.455478526952
# 708406888921178112    1.0    -1.00547338099   -0.455503501645
# 708803391141519360    1.0    -1.00545414228   -0.455514601914
# 675038539050954752    1.0    -1.00544695265   -0.455518750244
# 709000107476189184    1.0    -1.00544409981   -0.455520396314
# 710683600199553024    1.0    -1.00544244554   -0.455521350818
# 697926931564601345    1.0    -1.00537052602   -0.455562850402
# 667372837385076736    1.0    -1.00525537465   -0.455629305772
# 685300437977710592    1.0    -1.00523069395   -0.455643550902
# 671654735565479936    1.0    -1.00516627995   -0.455680731783
# 675302088008593412    1.0    -1.00500732451   -0.455772499786
# 686263164502196224    1.0    -1.00499541481   -0.455779376411
# 667782113257652224    1.0    -1.00497274276   -0.455792467542
# 672398155732885504    1.0    -1.00494413448   -0.455808986989
# 702149077232816130    1.0     -1.0048844194   -0.455843471028
# 696897146541490180    1.0    -1.00483953318   -0.455869393888
# 702914902919352320    1.0    -1.00477558293   -0.455906329856
# 688727918248357888    1.0    -1.00469874454   -0.455950714596
# 676240559229505537    1.0    -1.00439341047   -0.456127140211
# 708709511259787264    1.0    -1.00436180777   -0.456145405476
# 699339135400615936    1.0    -1.00427940118   -0.456193037915
# 674077235725266944    1.0    -1.00413318866   -0.456277566539
# 716283630927134722    1.0    -1.00385193242   -0.456440221716
# 675591853400436736    1.0    -1.00369000509   -0.456533899748
# 708806488391688192    1.0    -1.00339315217   -0.456705697001
#
#                                                                 words
# 706525326667550720  Its time to act and innovate to end the AIDS e...
# 685500898123083778  if You see this 13 symptoms . Do HIV Test Imme...
# 695750291338166272  We Know All We Need To Know To End The HIV Epi...
# 671757652762980352  RT SueDHellmann Go RED this # GivingTuesday RT...
# 690280713963188224             Know your # HIV status , get tested at
# 667667693240246272  RT rynajokanuzy WARNING There's A New Deadly D...
# 712971190860693504  RT JOYNER_XVI I am assuming this question is d...
# 675804767688372224  RT charms_lovely Female Student Infected 324 M...
# 686419247736606720  How to Survive a Plague is a touching film abo...
# 714240257625960448                        MadamLegend Finxly FPS AIDS
# 677140221381709824  RT Uncle_Moon215 Whats more stressful ? Waitin...
# 709583191535845376  RT mar1orie HIV drug could stop # skincancer b...
# 685497277918625793  RT wmtcfl Were ready to hit the road and bring...
# 717013167256121348  # Stigmabase HIV - Surgeons perform first HIV ...
# 708375577665769473  RT andizeisler I mean , technically that's tru...
# 692833356803760128  # GOODNEWSEVERYONE Researchers Just Took a Hug...
# 705158479846232065  RT willchegwidden Camilla Hawkins talking abou...
# 709219826217127936  RT 90swomen Iman and David Bowie at an AIDS be...
# 671839149725380609  Changing Policy to Address Violence and Trauma...
# 702877627518877696  Vaginal Ring amp # PrEP Updates from # CROI201...
# 697512318465413120  RT earmuffsss He had AIDS but ok let that be y...
# 705144099612053504  RT BrightpointNYC Join us amp KEEPIt100nyc iri...
# 709386625529290752  cdbucla RT PEPFAR RT together4girls 380k girls...
# 704547215889571841  Why a New Vaginal Ring could be a Game-Changer...
# 673373343136006144  Male circumcision can help reduce HIV in the w...
# 689338774627729408  RT jason2006 # Refugees account for 13 all new...
# 704748453071458304        RT breeeanaaaa They don't believe in AIDS .
# 704762004561633280  RT _iMechie don't catch AIDS trying to make me...
# 698393412232413184  Maybe it's time to repeal or # decriminalise t...
# 670555522735677440  RT MSF # HIV Despite better access to treatmen...
# ...                                                               ...
# 671804970618847232  RT SANTINORICE The reality is , had I been bor...
# 678767157287649281  RT ABSCBNNewsLife Ms . Philippines I would rai...
# 687062507735756800  It Took 20 Years For The Government To Pay For...
# 675926584356802560  Said that he wanted to give me HIV . I was lik...
# 710918709880160261  The Integrated # HIV Symposium was a huge succ...
# 678704737533886464  # TheApprentice Super Cond0m Invented Kills HI...
# 708406888921178112  RT voxdotcom UPDATE Hillary Clinton walks back...
# 708803391141519360  # RT # Follow # TopStories Hillary Clinton apo...
# 675038539050954752  New study suggests more sustainable way to tes...
# 709000107476189184  Elton John praises Hillary Clinton for HIV and...
# 710683600199553024  RT KentPage Sub-Saharan # Africa 7 in 10 new #...
# 697926931564601345  RT PositiveLiteCom Positive Quitting helping p...
# 667372837385076736  RT UNAIDS Let's # FastTrack the AIDS response ...
# 685300437977710592  RT xonecole This emotional video shows people ...
# 671654735565479936  RT medical_xpress Targeting # HIV 'reservoir' ...
# 675302088008593412       RT mylike32 SIGNS YOU MAY HAVE HIV INFECTION
# 686263164502196224  RT ExposeTPP # TPP countries citizens could lo...
# 667782113257652224  UK's latest HIV figures show the need to scale...
# 672398155732885504  Skimpy dressed girls are hot , decently dresse...
# 702149077232816130  CYDY - CytoDyn Initiates Phase 3 Monotherapy T...
# 696897146541490180  Its time to act and innovate to end the # AIDS...
# 702914902919352320  RT AP NJ hospital warns 213 patients of possib...
# 688727918248357888  Abeokuta if You see this 13 symptoms . Do HIV ...
# 676240559229505537  RT lovebird821 SIGNS YOU MAY HAVE HIV INFECTIO...
# 708709511259787264  RT joshualaporte # ImWithHer but am baffled an...
# 699339135400615936  AIDS N Birth Control Delivery App Offers Anti-...
# 674077235725266944                        Z2Raw_TM this Niqqa got HIV
# 716283630927134722  # cultura amp # HIV # Latino America RT briefl...
# 675591853400436736  Female Student Infected 324 Men With HIV As Re...
# 708806488391688192  RT ciccmaher Words I never expected to say nic...
#
# [624569 rows x 4 columns]

# %%
# lets restrict to prep tweets and truvada tweets only:
prep_tweets = []
truvada_tweets = []
side_effect_tweets = []

for words in df['words']:
    if 'PrEP' in words:
        prep_tweets.append(True)
    else:
        prep_tweets.append(False)
        
    if 'truvada' in words:
        truvada_tweets.append(True)
    else:
        truvada_tweets.append(False)
        
# lets look at side effects related tweets
for words in df['words']:
    if 'side effect' in words and 'prep' in words:
        side_effect_tweets.append(True)
    else:
        side_effect_tweets.append(False)

# %%
# most positive side effect tweets
df[side_effect_tweets][['words']][0:3].values
# Out:
# array([[ "Day 2 on # PrEP No side effects thus far . In 19 days , I'll have full protection . # TruvadaWhore # HIV # LGBT # prepster"]], dtype=object)

# %%
# most negative side effect tweets
df[side_effect_tweets][['words']][-4:-1].values
# Out:
# array([], shape=(0, 1), dtype=object)

# %%
# most positive tweet text, prep tweet text, truvada tweet text
df[['words']][0:3].append(df[prep_tweets][['words']][0:3]).append(df[truvada_tweets][['words']][0:3])

# %%
df[['words']][0:12].append(df[prep_tweets][['words']][0:4]).append(df[truvada_tweets][['words']][0:4])['words'].values

# %%
# most negative tweet text, prep tweet text, truvada tweet text
df[['words']][-4:-1].append(df[prep_tweets][['words']][-4:-1]).append(df[truvada_tweets][['words']][-4:-1])

# %%
df[['words']][-4:-1].append(df[prep_tweets][['words']][-4:-1]).append(df[truvada_tweets][['words']][-4:-1])['words'].values

# %% [markdown]
# # Topic modeling on positive and negative prep tweets

# %%
# topic modeling on top 10,000 (postive) PrEP tweets
corpus_pos = df[prep_tweets]['words'][0:10000]

# topic modeling on top 10,000 (negative) HIV tweets
corpus_neg = df[prep_tweets]['words'][-10000:-1]

# %%
from gensim.parsing.preprocessing import STOPWORDS
import re


STOPWORDS_ = ['rt', '', 'httpst', 'amp', 'https\'']

def clean_text(text):
    clean = re.sub(r'http.*$', '', text)
    clean = re.sub(r'[^a-zA-Z\s]', '', clean)

    clean = clean.lower()
    word_list = clean.split()
    word_list = [w for w in word_list if (w not in STOPWORDS_ and w not in STOPWORDS)]

    return word_list

corpus_pos = [clean_text(doc) for doc in corpus_pos]
corpus_neg = [clean_text(doc) for doc in corpus_neg]

# %%
from gensim.models.ldamodel import LdaModel
from gensim.models import TfidfModel
from gensim import corpora

def make_tfidf_corpra(texts):
    dictionary = corpora.Dictionary(texts)
    dictionary.filter_extremes(no_below=10, no_above=0.3, keep_n=100000)
    corpus = [dictionary.doc2bow(text) for text in texts]
    tfidf = TfidfModel(corpus)
    corpus = tfidf[corpus]
    
    return dictionary, corpus

dict_pos, corpus_pos = make_tfidf_corpra(corpus_pos)
dict_neg, corpus_neg = make_tfidf_corpra(corpus_neg)

if train:
    model_pos = LdaModel(corpus_pos, id2word=dict_pos, num_topics=10, iterations=50, passes=10)
    model_pos.save('../models/lda_sentiment_pos.model')
    
    model_neg = LdaModel(corpus_pos, id2word=dict_pos, num_topics=10, iterations=50, passes=10)
    model_neg.save('../models/lda_sentiment_neg.model')

else:
    model_pos = LdaModel.load('../models/lda_sentiment_pos.model')
    model_neg = LdaModel.load('../models/lda_sentiment_neg.model')

# %%
pd.DataFrame([row[1].split(' + ') for row in model_pos.print_topics(20)]).iloc[:,0:5]

# %%
pd.DataFrame([row[1].split(' + ') for row in model_neg.print_topics(20)]).iloc[:,0:5]
