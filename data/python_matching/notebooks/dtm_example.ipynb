# %% [markdown]
# # DTM (Figures 1, 2 and Tables 1, 2)
#
# This is adapted (partially) from https://github.com/piskvorky/gensim/blob/develop/docs/notebooks/dtm_example.ipynb

# %%
import json
import re

from gensim import corpora, utils
from gensim.models.wrappers.dtmmodel import DtmModel
import numpy as np
import pandas as pd

# %matplotlib inline
import seaborn

train = False

from gensim.parsing.preprocessing import STOPWORDS
# script author defined stop words
STOPWORDS_ = ['rt', '', 'httpst', 'amp']

# load the tweets
documents = []
time_seq = []
weeknum = ''
ds_fact = 3
with open('../data/c_twitter.json') as f_in:
    for i, l in enumerate(f_in):
        if (i % ds_fact == 0):
            index =+ 1
            c_twt = json.loads(l)

            # remove punctuation and stopwords for this analysis
            words = re.sub(r'[^a-zA-Z\s]', '', c_twt['text'])
            words = words.split()
            words = [w for w in words if (w not in STOPWORDS and w not in STOPWORDS_)]
            words = [bytes(w, 'utf-8') for w in words]

            # c_twt: {'weeknum': str, 'c_text': str, 'tags': [str]}
            documents.append(words)

            if weeknum != c_twt['weeknum']:
                time_seq.append(i // ds_fact)
                weeknum = c_twt['weeknum']
            
time_seq.append(len(documents))
y = time_seq[1:] + [0]
x = time_seq[:]
time_seq = []
for x, y in zip(x, y):
    time_seq.append(y - x)

del time_seq[-1]
time_seq
# Out:
# [7632,
#  8618,
#  21301,
#  10714,
#  7590,
#  2446,
#  7872,
#  8332,
#  7270,
#  6251,
#  2555,
#  11368,
#  7188,
#  16573,
#  13830,
#  31953,
#  11968,
#  9854,
#  7664,
#  7211]

# %%
from gensim.models import TfidfModel

dictionary = corpora.Dictionary(documents)
dictionary.filter_extremes(no_below=10, no_above=0.3, keep_n=100000)
corpus = [dictionary.doc2bow(doc) for doc in documents]

len(corpus)
# Out:
# 208190

# %%
# tfidf = TfidfModel(corpus)
# corpus = tfidf[corpus]
corpus[0]
# Out:
# [(83, 1),
#  (1771, 1),
#  (3027, 1),
#  (5582, 1),
#  (7110, 1),
#  (7613, 1),
#  (9010, 1),
#  (9080, 1)]

# %% [markdown]
# # Train model (or load model from file)

# %%
if train:
    dtm_binary_path = '/high_spd_work/sm_w2v/tools/dtm/dtm/dtm'
    model = DtmModel(dtm_binary_path, corpus, time_seq, num_topics=10,
                     id2word=dictionary, initialize_lda=True, rng_seed=0)
    model.save('../models/dtm_example.model')
else:
    model = DtmModel.load('../models/dtm_example.model')

# %% [markdown]
# # Figure 1, 2 and Table 1, 2: Dynamic Topic Modeling
#
# I'm proposing that in figures 1 and 2, we pick 2 topics from the Dynamic Topic Model, and describe the progression in time of these 2 topics with time series graphs, and tables 1 and 2 will be top 10 tables of these same topics over time
#
#
# Topic ID's 8, 7 and 3 are all interesting

# %%
# This cell just gets the week nums (YYYY-WW)

def make_weeknums():
    # first  week is 2015-47
    week = 47
    year = 2015
    weeknums = []
    for i in range(len(model.time_slices)):
        
        if len(str(week)) > 1:
            weeknums.append(str(year) + '-' + str(week))
        else:
            weeknums.append(str(year) + '-0' + str(week))
        week = week + 1

        if week > 53:
            year = year + 1
            week = 1
    
    return weeknums

weeknums = make_weeknums()

# %% [markdown]
# # Table 1: top 10 words associated with topic ID 3 over time
#
# note how 'prep' is absent from top ten in the beginning, then increases over time

# %%
for t_index in range(len(model.time_slices)):
    print("--- time slice: ", t_index, "\n")
    print(pd.DataFrame(model.show_topic(topicid=9, time=t_index, topn=10), columns=['Probability', 'Word']))
    print()
# Out:
# --- time slice:  0
#
#    Probability         Word
# 0     0.125361          You
# 1     0.053233           Do
# 2     0.042645  Immediately
# 3     0.030081         Read
# 4     0.028556       spread
# 5     0.026624     symptoms
# 6     0.024364       Please
# 7     0.022583      dentist
# 8     0.021792         Test
# 9     0.021305         porn
#
# --- time slice:  1
#
#    Probability             Word
# 0     0.135367              You
# 1     0.060020               Do
# 2     0.048579      Immediately
# 3     0.035626             Read
# 4     0.031385         symptoms
# 5     0.029296           Please
# 6     0.026617             Test
# 7     0.023979         AJEdinho
# 8     0.018696  dopeislandvines
# 9     0.018145           spread
#
# --- time slice:  2
#
#    Probability             Word
# 0     0.142136              You
# 1     0.069340               Do
# 2     0.057399      Immediately
# 3     0.045064             Read
# 4     0.039558         symptoms
# 5     0.038226           Please
# 6     0.035342             Test
# 7     0.028043         AJEdinho
# 8     0.015766  dopeislandvines
# 9     0.013304            Harry
#
# --- time slice:  3
#
#    Probability             Word
# 0     0.139440              You
# 1     0.079034               Do
# 2     0.067891      Immediately
# 3     0.057707             Read
# 4     0.051323           Please
# 5     0.051028         symptoms
# 6     0.047721             Test
# 7     0.031961         AJEdinho
# 8     0.012621            Harry
# 9     0.011182  dopeislandvines
#
# --- time slice:  4
#
#    Probability         Word
# 0     0.129085          You
# 1     0.087497           Do
# 2     0.078519  Immediately
# 3     0.072420         Read
# 4     0.068055       Please
# 5     0.065133     symptoms
# 6     0.063938         Test
# 7     0.033961     AJEdinho
# 8     0.009663        Harry
# 9     0.009114       Prince
#
# --- time slice:  5
#
#    Probability         Word
# 0     0.116431          You
# 1     0.093261           Do
# 2     0.087279  Immediately
# 3     0.087001         Read
# 4     0.086091       Please
# 5     0.082484         Test
# 6     0.079932     symptoms
# 7     0.032840     AJEdinho
# 8     0.009393      Tushbae
# 9     0.008022           If
#
# --- time slice:  6
#
#    Probability         Word
# 0     0.104783          You
# 1     0.097607       Please
# 2     0.097008         Read
# 3     0.096377         Test
# 4     0.095003           Do
# 5     0.091844  Immediately
# 6     0.091380     symptoms
# 7     0.028620     AJEdinho
# 8     0.012009      Tushbae
# 9     0.011727           If
#
# --- time slice:  7
#
#    Probability         Word
# 0     0.098732         Read
# 1     0.097795          You
# 2     0.096809         Test
# 3     0.095764     symptoms
# 4     0.094355       Please
# 5     0.093240           Do
# 6     0.091477  Immediately
# 7     0.024630           If
# 8     0.022458     AJEdinho
# 9     0.016194      Tushbae
#
# --- time slice:  8
#
#    Probability         Word
# 0     0.095944          You
# 1     0.095413         Read
# 2     0.095289     symptoms
# 3     0.090410           Do
# 4     0.090223         Test
# 5     0.088364  Immediately
# 6     0.078506       Please
# 7     0.036425           If
# 8     0.017244     AJEdinho
# 9     0.013212      Tushbae
#
# --- time slice:  9
#
#    Probability         Word
# 0     0.097037          You
# 1     0.091504     symptoms
# 2     0.089660         Read
# 3     0.086737           Do
# 4     0.083084  Immediately
# 5     0.082500         Test
# 6     0.057566       Please
# 7     0.026531           If
# 8     0.012799     AJEdinho
# 9     0.009173      Tushbae
#
# --- time slice:  10
#
#    Probability         Word
# 0     0.095894          You
# 1     0.082657     symptoms
# 2     0.080356         Read
# 3     0.079395           Do
# 4     0.074260         Test
# 5     0.073680  Immediately
# 6     0.038519       Please
# 7     0.015125           If
# 8     0.009277         Must
# 9     0.009037     AJEdinho
#
# --- time slice:  11
#
#    Probability         Word
# 0     0.091055          You
# 1     0.070098     symptoms
# 2     0.068818         Read
# 3     0.068803           Do
# 4     0.066267         Test
# 5     0.061251  Immediately
# 6     0.024689       Please
# 7     0.019171         Must
# 8     0.010855    hepatitis
# 9     0.009054     hospital
#
# --- time slice:  12
#
#    Probability         Word
# 0     0.083384          You
# 1     0.058661         Test
# 2     0.057022         Read
# 3     0.056993           Do
# 4     0.056314     symptoms
# 5     0.048221  Immediately
# 6     0.038960         Must
# 7     0.016079       Please
# 8     0.014661   tusholosho
# 9     0.013161    hepatitis
#
# --- time slice:  13
#
#    Probability         Word
# 0     0.075715          You
# 1     0.048379         Must
# 2     0.048205         Test
# 3     0.046162           Do
# 4     0.045964         Read
# 5     0.043220     symptoms
# 6     0.036788  Immediately
# 7     0.018551   tusholosho
# 8     0.016458    hepatitis
# 9     0.015487     patients
#
# --- time slice:  14
#
#    Probability         Word
# 0     0.070179          You
# 1     0.037498           Do
# 2     0.036302         Read
# 3     0.035500         Test
# 4     0.032094     symptoms
# 5     0.027915  Immediately
# 6     0.026410         Must
# 7     0.020630    hepatitis
# 8     0.017072     patients
# 9     0.013159           In
#
# --- time slice:  15
#
#    Probability         Word
# 0     0.063835          You
# 1     0.030025           Do
# 2     0.028028         Read
# 3     0.025358    hepatitis
# 4     0.024965         Test
# 5     0.023263     symptoms
# 6     0.020887  Immediately
# 7     0.018044     patients
# 8     0.017080     positive
# 9     0.014701           In
#
# --- time slice:  16
#
#    Probability       Word
# 0     0.056796        You
# 1     0.025709  hepatitis
# 2     0.024079         Do
# 3     0.021526       Read
# 4     0.020088   positive
# 5     0.017933   patients
# 6     0.017671       Test
# 7     0.017047   symptoms
# 8     0.016672   possible
# 9     0.016296   exposure
#
# --- time slice:  17
#
#    Probability       Word
# 0     0.052980        You
# 1     0.024960   positive
# 2     0.021073  hepatitis
# 3     0.020586         Do
# 4     0.019067   patients
# 5     0.018401         In
# 6     0.017821       Read
# 7     0.016168   possible
# 8     0.013764       Test
# 9     0.013580   symptoms
#
# --- time slice:  18
#
#    Probability       Word
# 0     0.050728        You
# 1     0.030017   positive
# 2     0.022138   patients
# 3     0.020960         In
# 4     0.018499         Do
# 5     0.017678  hepatitis
# 6     0.015996   possible
# 7     0.015696       Read
# 8     0.013715        got
# 9     0.013442        How
#
# --- time slice:  19
#
#    Probability       Word
# 0     0.049842        You
# 1     0.032716   positive
# 2     0.024125   patients
# 3     0.022488         In
# 4     0.017575         Do
# 5     0.016468  hepatitis
# 6     0.015719   possible
# 7     0.014783       Read
# 8     0.013845        got
# 9     0.013573        How

# %% [markdown]
# # Figure 1: key terms PrEP related
#
# also seeing nancy reagan:
# http://www.newyorker.com/news/daily-comment/hillary-clinton-nancy-reagan-and-aids
#
# also see transplants:
# http://hub.jhu.edu/2016/02/08/first-hiv-positive-kidney-liver-transplants

# %%
data = []
for t_index in range(len(model.time_slices)):
    words = model.show_topic(topicid=5, time=t_index, topn=1000)
        
    columns = ['PrEP', 'pill', 'prevention', 'drug', 'risk']
    row = []
    for col in columns:
        cell = [w[0] for w in words if w[1] == col]
        if not cell:
            cell = .000001
        else:
            cell = cell[0]
        row.append(cell)
    data.append(row)
    
df = pd.DataFrame(data, columns=columns, index=weeknums)
ax = df.plot(title='')
fig = ax.get_figure()
fig.savefig('DTMfig1.pdf', format='pdf')

# %% [markdown]
# # Fig2: World AIDS Day related:

# %%
for t_index in range(len(model.time_slices)):
    print("--- time slice: ", t_index, "\n")
    print(pd.DataFrame(model.show_topic(topicid=4, time=t_index, topn=10), columns=['Probability', 'Word']))
    print()
# Out:
# --- time slice:  0
#
#    Probability           Word
# 0     0.028307   WorldAIDSDay
# 1     0.022456            RED
# 2     0.021217           days
# 3     0.019818        provide
# 4     0.019346      treatment
# 5     0.019036      awareness
# 6     0.016189            Can
# 7     0.015884     lifesaving
# 8     0.015332  GivingTuesday
# 9     0.013781           help
#
# --- time slice:  1
#
#    Probability           Word
# 0     0.028963   WorldAIDSDay
# 1     0.023530            RED
# 2     0.021244           days
# 3     0.019869        provide
# 4     0.019826      treatment
# 5     0.019640      awareness
# 6     0.016306            Can
# 7     0.015799     lifesaving
# 8     0.015526  GivingTuesday
# 9     0.014074           help
#
# --- time slice:  2
#
#    Probability           Word
# 0     0.027478   WorldAIDSDay
# 1     0.023793            RED
# 2     0.020723      awareness
# 3     0.020145           days
# 4     0.019127      treatment
# 5     0.018852        provide
# 6     0.016073            Can
# 7     0.014726  GivingTuesday
# 8     0.014292     lifesaving
# 9     0.013956           help
#
# --- time slice:  3
#
#    Probability           Word
# 0     0.023754      awareness
# 1     0.019435   WorldAIDSDay
# 2     0.018902            RED
# 3     0.016100           days
# 4     0.015090            Can
# 5     0.014819        provide
# 6     0.014344      treatment
# 7     0.012651        Prevent
# 8     0.012037           help
# 9     0.010989  GivingTuesday
#
# --- time slice:  4
#
#    Probability          Word
# 0     0.028882     awareness
# 1     0.014036           RED
# 2     0.013414           got
# 3     0.013199          turn
# 4     0.012434  WorldAIDSDay
# 5     0.012408           Can
# 6     0.012276          days
# 7     0.012087          HIWE
# 8     0.011583          bout
# 9     0.011212         raise
#
# --- time slice:  5
#
#    Probability         Word
# 0     0.033875    awareness
# 1     0.015248        raise
# 2     0.013982          got
# 3     0.013824         turn
# 4     0.013230  Philippines
# 5     0.012150         bout
# 6     0.012056         HIWE
# 7     0.010872          RED
# 8     0.010858          bae
# 9     0.010012          Can
#
# --- time slice:  6
#
#    Probability         Word
# 0     0.031434    awareness
# 1     0.014120          got
# 2     0.013916         turn
# 3     0.013477      malaria
# 4     0.013433        raise
# 5     0.012053         bout
# 6     0.011606         HIWE
# 7     0.010901          bae
# 8     0.010857  Philippines
# 9     0.009224          RED
#
# --- time slice:  7
#
#    Probability       Word
# 0     0.026067  awareness
# 1     0.016369    malaria
# 2     0.013834        got
# 3     0.013538       turn
# 4     0.011472       bout
# 5     0.011009       HIWE
# 6     0.010845      raise
# 7     0.010629        bae
# 8     0.010203        The
# 9     0.008316        RED
#
# --- time slice:  8
#
#    Probability       Word
# 0     0.020734  awareness
# 1     0.015382    malaria
# 2     0.013456        got
# 3     0.012770       turn
# 4     0.011194        The
# 5     0.010795       bout
# 6     0.010507       HIWE
# 7     0.010228        bae
# 8     0.008693       Dont
# 9     0.008690      raise
#
# --- time slice:  9
#
#    Probability       Word
# 0     0.016560  awareness
# 1     0.012401        got
# 2     0.011797    malaria
# 3     0.011596      catch
# 4     0.011361        The
# 5     0.011308       turn
# 6     0.010632       Dont
# 7     0.009789       bout
# 8     0.009345       HIWE
# 9     0.009173        bae
#
# --- time slice:  10
#
#    Probability       Word
# 0     0.016762      catch
# 1     0.013713    jealous
# 2     0.013536  awareness
# 3     0.013097       Dont
# 4     0.011319        got
# 5     0.010454        The
# 6     0.009904       turn
# 7     0.009414      tryna
# 8     0.008763       bout
# 9     0.008532      Trump
#
# --- time slice:  11
#
#    Probability       Word
# 0     0.019210      catch
# 1     0.015579    jealous
# 2     0.015218       Dont
# 3     0.011388  awareness
# 4     0.011102      Trump
# 5     0.010578        got
# 6     0.009794      tryna
# 7     0.009704        The
# 8     0.008955       turn
# 9     0.008342     record
#
# --- time slice:  12
#
#    Probability       Word
# 0     0.017663      catch
# 1     0.016408      Trump
# 2     0.014971       Dont
# 3     0.014545    jealous
# 4     0.010484     record
# 5     0.010357        got
# 6     0.010001     Donald
# 7     0.009746  awareness
# 8     0.009440        The
# 9     0.009405      tryna
#
# --- time slice:  13
#
#    Probability      Word
# 0     0.026373     Trump
# 1     0.015423    Donald
# 2     0.014356    record
# 3     0.013991     catch
# 4     0.013112      Dont
# 5     0.012507   jealous
# 6     0.011146     Baron
# 7     0.011130     Sacha
# 8     0.010508      gets
# 9     0.010399  comments
#
# --- time slice:  14
#
#    Probability            Word
# 0     0.037582           Trump
# 1     0.023764          Donald
# 2     0.020908          record
# 3     0.019906        comments
# 4     0.018015         Reagans
# 5     0.016207           Baron
# 6     0.015819           Sacha
# 7     0.015376       statement
# 8     0.014621        Clintons
# 9     0.013650  HillaryClinton
#
# --- time slice:  15
#
#    Probability            Word
# 0     0.053333         Reagans
# 1     0.051668        comments
# 2     0.047956        Clintons
# 3     0.038531          record
# 4     0.035139  HillaryClinton
# 5     0.034924         Hillary
# 6     0.033812       statement
# 7     0.022701           Trump
# 8     0.011753          Donald
# 9     0.010165            Dont
#
# --- time slice:  16
#
#    Probability            Word
# 0     0.041540        comments
# 1     0.037428         Reagans
# 2     0.033546        Clintons
# 3     0.032562          record
# 4     0.027514       statement
# 5     0.025467  HillaryClinton
# 6     0.024392         Hillary
# 7     0.019238           Trump
# 8     0.017188            Dont
# 9     0.014365           catch
#
# --- time slice:  17
#
#    Probability            Word
# 0     0.026241            Dont
# 1     0.026058        comments
# 2     0.025227           catch
# 3     0.022273          record
# 4     0.022142         Reagans
# 5     0.021697         jealous
# 6     0.020813        Clintons
# 7     0.018570       statement
# 8     0.017076  HillaryClinton
# 9     0.016696           Trump
#
# --- time slice:  18
#
#    Probability       Word
# 0     0.037138      catch
# 1     0.033137       Dont
# 2     0.029118    jealous
# 3     0.018346   comments
# 4     0.016379     record
# 5     0.015838    Reagans
# 6     0.015729   Clintons
# 7     0.014544      tryna
# 8     0.014469      Trump
# 9     0.013799  statement
#
# --- time slice:  19
#
#    Probability       Word
# 0     0.043372      catch
# 1     0.037400       Dont
# 2     0.030406    jealous
# 3     0.015769   comments
# 4     0.015597      tryna
# 5     0.014435   Clintons
# 6     0.014406     record
# 7     0.014049    Reagans
# 8     0.013575      Trump
# 9     0.012294  statement

# %%
data = []
for t_index in range(len(model.time_slices)):
    words = model.show_topic(topicid=4, time=t_index, topn=1000)
        
    columns = ['WorldAIDSDay', 'Can', 'raise', 'awareness']
    row = []
    for col in columns:
        cell = [w[0] for w in words if w[1] == col]
        if not cell:
            cell = .000001
        else:
            cell = cell[0]
        row.append(cell)
    data.append(row)


df = pd.DataFrame(data, columns=columns, index=weeknums)
ax = df.plot(title='')
fig = ax.get_figure()
fig.savefig('DTMfig2.pdf', format='pdf')
